# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('my.csv')
print(df)
# Out:
#     time  traget   temp  avrg
# 0     12       96     4    74
# 1     12       63    54     5
# 2     45       63     5     5
# 3      4       63    45    45
# 4      5       52    45     5
# 5      4        5     8    28
# 6      6       25    12     9
# 7      5        8     1    63
# 8     89        8    33     6
# 9      5       57    53     8
# 10     6        4     5     5
# 11     5        7   353     2
# 12     6        4    55     5
# 13     5        1   565    55
# 14    68      124     5    12
# 15    66        6    22    36
# 16    25        6     8    78
# 17     5       56    28    56
# 18    55      565     8    78

# %%
x = df.drop('temp',axis=1)
y=df.temp

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split (x,y ,test_size =0.2,random_state=10 )
print("training set shape:",x_train.shape,y_train.shape)
print("testing set shape:",x_test.shape,y_test.shape )
# Out:
# training set shape: (15, 3) (15,)
# testing set shape: (4, 3) (4,)

# %%
from sklearn.linear_model import LinearRegression

# %%
#creating a model 
lr=LinearRegression()

# %%
#model is learing 
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# to evaluate the perfomance of model 
y_pred = lr.predict(x_test)
y_pred.shape
# Out:
# (4,)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2 = r2_score(y_test,y_pred)
mse = mean_absolute_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("R2 score",r2)
print("mean square error:",mse)
print("intercept",mae)
# Out:
# R2 score -58.756766977911006
# mean square error: 130.75349173965677
# intercept 130.75349173965677

# %%
 import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_pred,alpha=0.5)

plt.plot([y.min(),y.max(),],[y.min(),y.max()],color = "red")
plt.xlabel("actual values")
plt.ylabel("predicted values")
plt.title("pridicted compared to actual value(Linear Regression)")
# Out:
# Text(0.5, 1.0, 'pridicted compared to actual value(Linear Regression)')

# %%
plt.scatter(y_pred,y_test - y_pred,alpha=0.5)
plt.xlabel("actual values")
plt.ylabel("predicted values")
plt.title("residual plot (Linear Regression)")
plt.show()

# %%
#sir don't mind the values ,I created the data set that's the reason it is not proper
